# %%
import matplotlib.pyplot as plt
import sys
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_context("talk")

sys.path.append('./Functions/')
from readDensidadePop import readDensidadePop

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_excel('./Files/DensidadePopulacional.xlsx', skiprows=11)

# %%
df.head()
# Out:
#   Âmbito Geográfico               Anos   2001   2009   2010   2011   2012  \
# 0         NUTS 2013           Portugal  112.5  114.6  114.7  114.5    114
# 1            NUTS I         Continente  110.9  112.9  112.9  112.7  112.3
# 2           NUTS II              Norte  173.2  174.3  173.8  173.4  172.7
# 3          NUTS III         Alto Minho  112.7  111.4  110.9  110.3  109.6
# 4         Município  Arcos de Valdevez   55.2     52   51.5     51   50.4
#
#     2013   2014   2015  ... Unnamed: 246 Unnamed: 247 Unnamed: 248  \
# 0  113.4  112.8  112.3  ...          NaN          NaN          NaN
# 1  111.6    111  110.6  ...          NaN          NaN          NaN
# 2  171.7  170.7  169.7  ...          NaN          NaN          NaN
# 3  108.7  107.7  106.9  ...          NaN          NaN          NaN
# 4   49.8   49.2   48.6  ...          NaN          NaN          NaN
#
#   Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252 Unnamed: 253  \
# ...

# %%
df.keys()
# Out:
# Index(['Âmbito Geográfico',              'Anos',                2001,
#                       2009,                2010,                2011,
#                       2012,                2013,                2014,
#                       2015,
#        ...
#             'Unnamed: 246',      'Unnamed: 247',      'Unnamed: 248',
#             'Unnamed: 249',      'Unnamed: 250',      'Unnamed: 251',
#             'Unnamed: 252',      'Unnamed: 253',      'Unnamed: 254',
#             'Unnamed: 255'],
#       dtype='object', length=256)

# %%
df = readDensidadePop()

# %%
df.head()
# Out:
#   Âmbito Geográfico               Anos   2001   2009   2010   2011   2012  \
# 0         NUTS 2013           Portugal  112.5  114.6  114.7  114.5    114
# 1            NUTS I         Continente  110.9  112.9  112.9  112.7  112.3
# 2           NUTS II              Norte  173.2  174.3  173.8  173.4  172.7
# 3          NUTS III         Alto Minho  112.7  111.4  110.9  110.3  109.6
# 4         Município  Arcos de Valdevez   55.2     52   51.5     51   50.4
#
#     2013   2014   2015   2016   2017   2018
# 0  113.4  112.8  112.3    112  111.7  111.5
# 1  111.6    111  110.6  110.3    110  109.8
# 2  171.7  170.7  169.7  168.9  168.2  167.9
# 3  108.7  107.7  106.9  105.9    105  104.4
# 4   49.8   49.2   48.6     48   47.4     47

# %%
categs = df['Âmbito Geográfico'].unique()

# %%
categs
# Out:
# array(['NUTS 2013', 'NUTS I', 'NUTS II', 'NUTS III', 'Município'],
#       dtype=object)

# %%
df.tail(30)
# Out:
#                                      Âmbito Geográfico                 Anos  \
# 347                                          Município        Ribeira Brava
# 348                                          Município           Santa Cruz
# 349                                          Município              Santana
# 350                                          Município          São Vicente
# 351                                           NUTS III  Ilha de Porto Santo
# 352                                          Município          Porto Santo
# 353                                                NaN                  NaN
# 354                                                NaN                  NaN
# 355                                                NaN                  NaN
# 356                                                NaN                  NaN
# 357                             Densidade populacional                  NaN
# ...

# %%
df.tail()
# Out:
#     Âmbito Geográfico                 Anos   2001   2009   2010   2011   2012  \
# 348         Município           Santa Cruz  448.9    505  520.4  528.2  531.4
# 349         Município              Santana   91.2   83.1   81.6   79.9   78.2
# 350         Município          São Vicente   76.5   74.1   73.2   71.8   70.5
# 351          NUTS III  Ilha de Porto Santo  112.7  125.6  127.6  127.6    126
# 352         Município          Porto Santo  112.7  125.6  127.6  127.6    126
#
#       2013   2014   2015   2016   2017   2018
# 348  535.9    538  538.6  539.6  542.6    547
# 349   76.8   75.4     74   72.6   71.7     71
# 350   69.4     68   66.7   65.8   65.4   65.3
# 351    125  122.7  121.3  120.3  120.1  120.3
# 352    125  122.7  121.3  120.3  120.1  120.3

# %%
test = df[df['Âmbito Geográfico']=='NUTS II']

# %%
test.head()
# Out:
#     Âmbito Geográfico                          Anos   2001   2009   2010  \
# 2             NUTS II                         Norte  173.2  174.3  173.8
# 97            NUTS II                        Centro   83.3     83   82.8
# 206           NUTS II  Área Metropolitana de Lisboa  899.6    933  937.9
# 226           NUTS II                      Alentejo   24.6   24.2   24.1
# 290           NUTS II                       Algarve   79.5   88.7   89.8
#
#       2011   2012   2013   2014   2015   2016   2017   2018
# 2    173.4  172.7  171.7  170.7  169.7  168.9  168.2  167.9
# 97    82.4   81.8   81.2   80.6   80.2   79.8   79.4   78.9
# 206    941  940.3  932.9  931.4  932.2  934.3  937.7  941.9
# 226   23.9   23.8   23.6   23.4   23.1   22.8   22.6   22.4
# 290   89.8   89.1   88.7   88.4   88.4   88.4   88.2   87.9

# %%
test.rename(columns={'Anos':'Zona'}, inplace=True)

# %%
test.head()
# Out:
#     Âmbito Geográfico                          Zona   2001   2009   2010  \
# 2             NUTS II                         Norte  173.2  174.3  173.8
# 97            NUTS II                        Centro   83.3     83   82.8
# 206           NUTS II  Área Metropolitana de Lisboa  899.6    933  937.9
# 226           NUTS II                      Alentejo   24.6   24.2   24.1
# 290           NUTS II                       Algarve   79.5   88.7   89.8
#
#       2011   2012   2013   2014   2015   2016   2017   2018
# 2    173.4  172.7  171.7  170.7  169.7  168.9  168.2  167.9
# 97    82.4   81.8   81.2   80.6   80.2   79.8   79.4   78.9
# 206    941  940.3  932.9  931.4  932.2  934.3  937.7  941.9
# 226   23.9   23.8   23.6   23.4   23.1   22.8   22.6   22.4
# 290   89.8   89.1   88.7   88.4   88.4   88.4   88.2   87.9

# %%
qua = df.transpose()

# %%
qua.columns = qua.iloc[1]

# %%
qua[2:]['Norte'].plot()

# %%
test.Zona.unique()
# Out:
# array(['Alto Minho', 'Cávado', 'Ave', 'Área Metropolitana do Porto',
#        'Alto Tâmega', 'Tâmega e Sousa', 'Douro',
#        'Terras de Trás-os-Montes', 'Oeste', 'Região de Aveiro',
#        'Região de Coimbra', 'Região de Leiria', 'Viseu Dão Lafões',
#        'Beira Baixa', 'Médio Tejo', 'Beiras e Serra da Estrela',
#        'Área Metropolitana de Lisboa', 'Alentejo Litoral',
#        'Baixo Alentejo', 'Lezíria do Tejo', 'Alto Alentejo',
#        'Alentejo Central', 'Algarve', 'Ilha de Santa Maria',
#        'Ilha de São Miguel', 'Ilha Terceira', 'Ilha Graciosa',
#        'Ilha de São Jorge', 'Ilha do Pico', 'Ilha do Faial',
#        'Ilha das Flores', 'Ilha do Corvo', 'Ilha da Madeira',
#        'Ilha de Porto Santo'], dtype=object)

# %%
listyears = [2001,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]
zona = 'Douro'

plt.plot(listyears, np.squeeze(test[test['Zona']==zona][listyears].values), 'o-')
